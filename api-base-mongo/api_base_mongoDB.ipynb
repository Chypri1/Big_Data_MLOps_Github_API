# %%
# Configuration
URL_LOCAL = "http://localhost:8080"
URL_AZURE = "https://api-base-fastapi-mpt-dkhjb0cydga2aydc.canadacentral-01.azurewebsites.net"

# %%
# Ajout de pickel dans une variable repositories
repositories = "" # pickle

# %%
import requests

def appel_api_base_add_data(url = URL_LOCAL, datas):
    url = url + "/add_data"
    response = requests.post(url,json=datas)
    print(f"code http: "+str(response.status_code))
    print(response.text)

appel_api_base_add_data(repositories)
# Out:
#   Cell In[22], line 3
#     def appel_api_base_add_data(url = URL_LOCAL, datas):
#                                                  ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
import requests
    
def appel_api_base_show_data(url = URL_LOCAL,page = 1,page_size = 10000):
    url = url +"/show_data?page="+str(page)+"&page_size="+str(page_size)
    response = requests.get(url)
    print(f"code http: "+str(response.status_code))
    return (response.text)
    
# appel_api_github_recup_jour()
reponse = appel_api_base_show_data()
print(reponse)
# Out:
# code http: 200
# {"page":1,"page_size":10000,"total_pages":1,"total_documents":30,"data":[{"id":70107786,"node_id":"MDEwOlJlcG9zaXRvcnk3MDEwNzc4Ng==","name":"next.js","full_name":"vercel/next.js","private":false,"owner":{"login":"vercel","id":14985020,"html_url":"https://github.com/vercel"},"html_url":"https://github.com/vercel/next.js","description":"The React Framework","fork":false,"created_at":"2016-10-05T23:32:51","updated_at":"2025-03-04T19:07:15","pushed_at":"2025-03-04T19:16:57","language":"JavaScript","forks_count":27818,"stargazers_count":129870,"watchers_count":129870,"open_issues_count":3197},{"id":71583602,"node_id":"MDEwOlJlcG9zaXRvcnk3MTU4MzYwMg==","name":"cs-video-courses","full_name":"Developer-Y/cs-video-courses","private":false,"owner":{"login":"Developer-Y","id":22699926,"html_url":"https://github.com/Developer-Y"},"html_url":"https://github.com/Developer-Y/cs-video-courses","description":"List of Computer Science courses with video lectures.","fork":false,"created_at":"2016-10-21T17:02:11","updated_at":"2025-03-04T18:07:56","pushed_at":"2025-03-04T18:07:41","language":null,"forks_count":9230,"stargazers_count":68236,"watchers_count":68236,"open_issues_count":2},{"id":71220757,"node_id":"MDEwOlJlcG9zaXRvcnk3MTIyMDc1Nw==","name":"PayloadsAllTheThings","full_name":"swisskyrepo/PayloadsAllTheThings","private":false,"owner":{"login":"swisskyrepo","id":12152583,"html_url":"https://github.com/swisskyrepo"},"html_url":"https://github.com/swisskyrepo/PayloadsAllTheThings","description":"A list of useful payloads and bypass for Web Application Security and Pentest/CTF","fork":false,"created_at":"2016-10-18T07:29:07","updated_at":"2025-03-04T18:36:40","pushed_at":"2025-02-19T20:09:26","language":"Python","forks_count":15071,"stargazers_count":63629,"watchers_count":63629,"open_issues_count":16},{"id":71948498,"node_id":"MDEwOlJlcG9zaXRvcnk3MTk0ODQ5OA==","name":"localstack","full_name":"localstack/localstack","private":false,"owner":{"login":"localstack","id":28732122,"html_url":"https://github.com/localstack"},"html_url":"https://github.com/localstack/localstack","description":"💻 A fully functional local AWS cloud stack. Develop and test your cloud & Serverless apps offline","fork":false,"created_at":"2016-10-25T23:48:03","updated_at":"2025-03-04T18:21:56","pushed_at":"2025-03-04T16:19:21","language":"Python","forks_count":4093,"stargazers_count":57895,"watchers_count":57895,"open_issues_count":329},{"id":71995937,"node_id":"MDEwOlJlcG9zaXRvcnk3MTk5NTkzNw==","name":"nuxt","full_name":"nuxt/nuxt","private":false,"owner":{"login":"nuxt","id":23360933,"html_url":"https://github.com/nuxt"},"html_url":"https://github.com/nuxt/nuxt","description":"The Intuitive Vue Framework.","fork":false,"created_at":"2016-10-26T11:18:47","updated_at":"2025-03-04T17:34:35","pushed_at":"2025-03-04T17:20:37","language":"TypeScript","forks_count":5163,"stargazers_count":56331,"watchers_count":56331,"open_issues_count":901},{"id":70905478,"node_id":"MDEwOlJlcG9zaXRvcnk3MDkwNTQ3OA==","name":"Deep-Learning-Papers-Reading-Roadmap","full_name":"floodsung/Deep-Learning-Papers-Reading-Roadmap","private":false,"owner":{"login":"floodsung","id":3880963,"html_url":"https://github.com/floodsung"},"html_url":"https://github.com/floodsung/Deep-Learning-Papers-Reading-Roadmap","description":"Deep Learning papers reading roadmap for anyone who are eager to learn this amazing tech!","fork":false,"created_at":"2016-10-14T11:49:48","updated_at":"2025-03-04T16:18:44","pushed_at":"2022-11-27T13:18:32","language":"Python","forks_count":7349,"stargazers_count":38815,"watchers_count":38815,"open_issues_count":89},{"id":71932349,"node_id":"MDEwOlJlcG9zaXRvcnk3MTkzMjM0OQ==","name":"ray","full_name":"ray-project/ray","private":false,"owner":{"login":"ray-project","id":22125274,"html_url":"https://github.com/ray-project"},"html_url":"https://github.com/ray-project/ray","description":"Ray is an AI compute engine. Ray consists of a core distributed runtime and a set of AI Libraries for ...

# %%
import requests

def appel_api_base_show_ingestion_date(url = URL_LOCAL):
    url = url +"/get_ingestion_date"
    response = requests.get(url)
    print(f"code http: "+str(response.status_code))
    print(response.text)

appel_api_base_show_ingestion_date()
# Out:
# code http: 200
# {"data":[{"id":70107786,"node_id":"MDEwOlJlcG9zaXRvcnk3MDEwNzc4Ng==","ingestion_date":"2025-03-04T19:17:36.767008"},{"id":71583602,"node_id":"MDEwOlJlcG9zaXRvcnk3MTU4MzYwMg==","ingestion_date":"2025-03-04T19:17:36.767935"},{"id":71220757,"node_id":"MDEwOlJlcG9zaXRvcnk3MTIyMDc1Nw==","ingestion_date":"2025-03-04T19:17:36.767955"},{"id":71948498,"node_id":"MDEwOlJlcG9zaXRvcnk3MTk0ODQ5OA==","ingestion_date":"2025-03-04T19:17:36.767961"},{"id":71995937,"node_id":"MDEwOlJlcG9zaXRvcnk3MTk5NTkzNw==","ingestion_date":"2025-03-04T19:17:36.767965"},{"id":70905478,"node_id":"MDEwOlJlcG9zaXRvcnk3MDkwNTQ3OA==","ingestion_date":"2025-03-04T19:17:36.767969"},{"id":71932349,"node_id":"MDEwOlJlcG9zaXRvcnk3MTkzMjM0OQ==","ingestion_date":"2025-03-04T19:17:36.767974"},{"id":70198875,"node_id":"MDEwOlJlcG9zaXRvcnk3MDE5ODg3NQ==","ingestion_date":"2025-03-04T19:17:36.767981"},{"id":72343657,"node_id":"MDEwOlJlcG9zaXRvcnk3MjM0MzY1Nw==","ingestion_date":"2025-03-04T19:17:36.767986"},{"id":70431106,"node_id":"MDEwOlJlcG9zaXRvcnk3MDQzMTEwNg==","ingestion_date":"2025-03-04T19:17:36.767990"},{"id":71056775,"node_id":"MDEwOlJlcG9zaXRvcnk3MTA1Njc3NQ==","ingestion_date":"2025-03-04T19:17:36.767994"},{"id":70198664,"node_id":"MDEwOlJlcG9zaXRvcnk3MDE5ODY2NA==","ingestion_date":"2025-03-04T19:17:36.767999"},{"id":71487058,"node_id":"MDEwOlJlcG9zaXRvcnk3MTQ4NzA1OA==","ingestion_date":"2025-03-04T19:17:36.768002"},{"id":70104825,"node_id":"MDEwOlJlcG9zaXRvcnk3MDEwNDgyNQ==","ingestion_date":"2025-03-04T19:17:36.768007"},{"id":72477752,"node_id":"MDEwOlJlcG9zaXRvcnk3MjQ3Nzc1Mg==","ingestion_date":"2025-03-04T19:17:36.768010"},{"id":71939872,"node_id":"MDEwOlJlcG9zaXRvcnk3MTkzOTg3Mg==","ingestion_date":"2025-03-04T19:17:36.768015"},{"id":72396492,"node_id":"MDEwOlJlcG9zaXRvcnk3MjM5NjQ5Mg==","ingestion_date":"2025-03-04T19:17:36.768025"},{"id":69798748,"node_id":"MDEwOlJlcG9zaXRvcnk2OTc5ODc0OA==","ingestion_date":"2025-03-04T19:17:36.768029"},{"id":72103891,"node_id":"MDEwOlJlcG9zaXRvcnk3MjEwMzg5MQ==","ingestion_date":"2025-03-04T19:17:36.768034"},{"id":70908208,"node_id":"MDEwOlJlcG9zaXRvcnk3MDkwODIwOA==","ingestion_date":"2025-03-04T19:17:36.768038"},{"id":70318556,"node_id":"MDEwOlJlcG9zaXRvcnk3MDMxODU1Ng==","ingestion_date":"2025-03-04T19:17:36.768042"},{"id":69953445,"node_id":"MDEwOlJlcG9zaXRvcnk2OTk1MzQ0NQ==","ingestion_date":"2025-03-04T19:17:36.768046"},{"id":71551629,"node_id":"MDEwOlJlcG9zaXRvcnk3MTU1MTYyOQ==","ingestion_date":"2025-03-04T19:17:36.768050"},{"id":70777180,"node_id":"MDEwOlJlcG9zaXRvcnk3MDc3NzE4MA==","ingestion_date":"2025-03-04T19:17:36.768053"},{"id":71297170,"node_id":"MDEwOlJlcG9zaXRvcnk3MTI5NzE3MA==","ingestion_date":"2025-03-04T19:17:36.768058"},{"id":71293321,"node_id":"MDEwOlJlcG9zaXRvcnk3MTI5MzMyMQ==","ingestion_date":"2025-03-04T19:17:36.768061"},{"id":70100622,"node_id":"MDEwOlJlcG9zaXRvcnk3MDEwMDYyMg==","ingestion_date":"2025-03-04T19:17:36.768065"},{"id":70342215,"node_id":"MDEwOlJlcG9zaXRvcnk3MDM0MjIxNQ==","ingestion_date":"2025-03-04T19:17:36.768069"},{"id":70127218,"node_id":"MDEwOlJlcG9zaXRvcnk3MDEyNzIxOA==","ingestion_date":"2025-03-04T19:17:36.768073"},{"id":71323749,"node_id":"MDEwOlJlcG9zaXRvcnk3MTMyMzc0OQ==","ingestion_date":"2025-03-04T19:17:36.768076"}],"message":"Données récupérées avec succès"}

# %%
import requests

def appel_api_base_delete_collection( collection_name: str,url = URL_LOCAL):
    url = url+"/delete_collection/"+collection_name
    response = requests.delete(url)
    print(f"code http: "+str(response.status_code))
    print(response.text)

appel_api_base_delete_collection("my_ingestion_data_collection")
# Out:
# code http: 200
# {"message":"Collection 'my_ingestion_data_collection' supprimée avec succès"}

# %%
import requests

def appel_api_base_count_collection( url = URL_LOCAL):
    url = url+"/count"
    response = requests.get(url)
    print(f"code http: "+str(response.status_code))
    print(f"count : "+str(response.text))

appel_api_base_count_collection()
# Out:
# code http: 200
# count : 30
