# %%
import json
import requests
import pandas as pd

# Charger les données
base_url = "https://api-base-fastapi-mpt-dkhjb0cydga2aydc.canadacentral-01.azurewebsites.net"
api_key = ""
with open('../api.json', 'r') as file:
    api_key = json.load(file)["GH_API_KEY"]

def get_call(paths,url=base_url, params=None, header=None):
    url = f"{base_url}/{paths}"
    response = requests.get(url, params=params, headers=header)
    if response.status_code == 200:
        return response.json()
    elif response.status_code == 403:
        print("La patience est d'or. Enculé")
        response = requests.get(url, params=params, headers=header)
        return response.json()
    else:
        print(f"Error: {response.status_code} - {response.json().get('message', 'Unknown error')}")
        return None
repositories = get_call(paths="show_data",params={"page_size":10,"page":1})
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/asyncio/base_events.py", line 640, in run_forever
#     self._run_once()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/asyncio/base_events.py", line 1992, in _run_once
#     handle._run()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/ts/kww6z2z510xb35njpx1_8q8m0000gn/T/ipykernel_13685/3553741402.py", line 3, in <module>
#     import pandas as pd
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/asyncio/base_events.py", line 640, in run_forever
#     self._run_once()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/asyncio/base_events.py", line 1992, in _run_once
#     handle._run()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/ts/kww6z2z510xb35njpx1_8q8m0000gn/T/ipykernel_13685/3553741402.py", line 3, in <module>
#     import pandas as pd
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/Users/apple/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.

# %%
print(repositories)
# Out:
# {'page': 1, 'page_size': 10, 'total_pages': 14831, 'total_documents': 148301, 'data': [{'id': 781064102, 'node_id': 'R_kgDOLo4Xpg', 'name': 'CodeLibrary', 'full_name': 'sabbir-noyon/CodeLibrary', 'private': False, 'owner': {'login': 'sabbir-noyon', 'id': 100969574, 'html_url': 'https://github.com/sabbir-noyon'}, 'html_url': 'https://github.com/sabbir-noyon/CodeLibrary', 'description': None, 'fork': False, 'created_at': '2024-04-02T17:21:51Z', 'updated_at': '2025-01-23T23:42:39Z', 'pushed_at': '2024-04-03T16:13:28Z', 'language': 'C', 'forks_count': 2, 'stargazers_count': 9, 'watchers_count': 9, 'open_issues_count': 1}, {'id': 780981597, 'node_id': 'R_kgDOLozVXQ', 'name': 'meticulous-typescript-api', 'full_name': 'MeticulousHome/meticulous-typescript-api', 'private': False, 'owner': {'login': 'MeticulousHome', 'id': 98115466, 'html_url': 'https://github.com/MeticulousHome'}, 'html_url': 'https://github.com/MeticulousHome/meticulous-typescript-api', 'description': 'Typescript / axios based package to interact with the meticulous API', 'fork': False, 'created_at': '2024-04-02T14:26:33Z', 'updated_at': '2025-02-08T13:59:55Z', 'pushed_at': '2025-02-08T14:00:07Z', 'language': 'TypeScript', 'forks_count': 0, 'stargazers_count': 9, 'watchers_count': 9, 'open_issues_count': 0}, {'id': 781057044, 'node_id': 'R_kgDOLo38FA', 'name': 'Portfolio-webpage', 'full_name': 'muhsansattar/Portfolio-webpage', 'private': False, 'owner': {'login': 'muhsansattar', 'id': 90345731, 'html_url': 'https://github.com/muhsansattar'}, 'html_url': 'https://github.com/muhsansattar/Portfolio-webpage', 'description': 'This is portfolio website ', 'fork': False, 'created_at': '2024-04-02T17:06:13Z', 'updated_at': '2024-09-30T09:04:43Z', 'pushed_at': '2024-04-02T17:18:58Z', 'language': 'HTML', 'forks_count': 0, 'stargazers_count': 9, 'watchers_count': 9, 'open_issues_count': 0}, {'id': 780683758, 'node_id': 'R_kgDOLohJ7g', 'name': 'Smart_Causal_Inference', 'full_name': 'CausalInferenceLab/Smart_Causal_Inference', 'private': False, 'owner': {'login': 'CausalInferenceLab', 'id': 114298781, 'html_url': 'https://github.com/CausalInferenceLab'}, 'html_url': 'https://github.com/CausalInferenceLab/Smart_Causal_Inference', 'description': '"실무로 통하는 인과추론 with 파이썬" 스터디를 하고 내용을 정리한 깃허브입니다.', 'fork': False, 'created_at': '2024-04-02T00:52:36Z', 'updated_at': '2024-11-18T06:43:27Z', 'pushed_at': '2024-09-20T12:14:41Z', 'language': 'HTML', 'forks_count': 2, 'stargazers_count': 9, 'watchers_count': 9, 'open_issues_count': 0}, {'id': 780839892, 'node_id': 'R_kgDOLoqr1A', 'name': 'Funny-Eval-Meme', 'full_name': 'Crump3tte/Funny-Eval-Meme', 'private': False, 'owner': {'login': 'Crump3tte', 'id': 157238134, 'html_url': 'https://github.com/Crump3tte'}, 'html_url': 'https://github.com/Crump3tte/Funny-Eval-Meme', 'description': None, 'fork': False, 'created_at': '2024-04-02T09:00:46Z', 'updated_at': '2025-01-15T16:35:25Z', 'pushed_at': '2024-04-02T09:35:08Z', 'language': None, 'forks_count': 3, 'stargazers_count': 9, 'watchers_count': 9, 'open_issues_count': 0}, {'id': 781078326, 'node_id': 'R_kgDOLo5PNg', 'name': 'Bmarket', 'full_name': 'moyu3739/Bmarket', 'private': False, 'owner': {'login': 'moyu3739', 'id': 149601699, 'html_url': 'https://github.com/moyu3739'}, 'html_url': 'https://github.com/moyu3739/Bmarket', 'description': '这是一个使用python爬虫抓取ss市集的脚本', 'fork': False, 'created_at': '2024-04-02T17:52:37Z', 'updated_at': '2025-01-17T04:06:22Z', 'pushed_at': '2024-09-03T07:09:06Z', 'language': 'Python', 'forks_count': 0, 'stargazers_count': 9, 'watchers_count': 9, 'open_issues_count': 1}, {'id': 781018011, 'node_id': 'R_kgDOLo1jmw', 'name': 'Resonance-Stuff', 'full_name': 'The-Original-Reth/Resonance-Stuff', 'private': False, 'owner': {'login': 'The-Original-Reth', 'id': 96796866, 'html_url': 'https://github.com/The-Original-Reth'}, 'html_url': 'https://github.com/The-Original-Reth/Resonance-Stuff', 'description': None, 'fork': False, 'created_at': '2024-04-02T15:42:26Z', 'updated_at': '2 ...

# %%
import pandas as pd
df = pd.DataFrame(repositories['data'])
# df.to_pickle("./repositories_data.pkl")
# df = df['language'].value_counts()[df['language'].value_counts()>10]

# %%
import pandas as pd
import numpy
# df = pd.read_pickle("./repositories_data.pkl")
df = df[~df["language"].isin(["Python", "None"])]
df = df.dropna(subset=["language"])
df
# Out:
#           id       node_id                       name  \
# 0  781064102  R_kgDOLo4Xpg                CodeLibrary
# 1  780981597  R_kgDOLozVXQ  meticulous-typescript-api
# 2  781057044  R_kgDOLo38FA          Portfolio-webpage
# 3  780683758  R_kgDOLohJ7g     Smart_Causal_Inference
# 8  781040117  R_kgDOLo259Q              DSA-WITH-JAVA
#
#                                    full_name  private  \
# 0                   sabbir-noyon/CodeLibrary    False
# 1   MeticulousHome/meticulous-typescript-api    False
# 2             muhsansattar/Portfolio-webpage    False
# 3  CausalInferenceLab/Smart_Causal_Inference    False
# 8                   sanyog2005/DSA-WITH-JAVA    False
#
#                                                owner  \
# 0  {'login': 'sabbir-noyon', 'id': 100969574, 'ht...
# 1  {'login': 'MeticulousHome', 'id': 98115466, 'h...
# 2  {'login': 'muhsansattar', 'id': 90345731, 'htm...
# 3  {'login': 'CausalInferenceLab', 'id': 11429878...
# 8  {'login': 'sanyog2005', 'id': 142544426, 'html...
#
#                                             html_url  \
# 0        https://github.com/sabbir-noyon/CodeLibrary
# 1  https://github.com/MeticulousHome/meticulous-t...
# 2  https://github.com/muhsansattar/Portfolio-webpage
# 3  https://github.com/CausalInferenceLab/Smart_Ca...
# 8        https://github.com/sanyog2005/DSA-WITH-JAVA
#
#                                          description   fork  \
# 0                                               None  False
# 1  Typescript / axios based package to interact w...  False
# 2                         This is portfolio website   False
# 3    "실무로 통하는 인과추론 with 파이썬" 스터디를 하고 내용을 정리한 깃허브입니다.  False
# 8                                               None  False
#
#              created_at            updated_at             pushed_at  \
# 0  2024-04-02T17:21:51Z  2025-01-23T23:42:39Z  2024-04-03T16:13:28Z
# 1  2024-04-02T14:26:33Z  2025-02-08T13:59:55Z  2025-02-08T14:00:07Z
# 2  2024-04-02T17:06:13Z  2024-09-30T09:04:43Z  2024-04-02T17:18:58Z
# 3  2024-04-02T00:52:36Z  2024-11-18T06:43:27Z  2024-09-20T12:14:41Z
# 8  2024-04-02T16:30:38Z  2025-01-01T21:47:54Z  2025-01-01T21:47:51Z
#
#      language  forks_count  stargazers_count  watchers_count  \
# 0           C            2                 9               9
# 1  TypeScript            0                 9               9
# 2        HTML            0                 9               9
# 3        HTML            2                 9               9
# 8        Java            0                 8               8
#
#    open_issues_count
# 0                  1
# 1                  0
# 2                  0
# 3                  0
# 8                  0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
sns.countplot(y=df["language"], order=df["language"].value_counts().index)
plt.title("Distribution des langages dans le dataset")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       4 plt.figure(figsize=(12, 5))
#
# File ~/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/seaborn/__init__.py:2
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File ~/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/seaborn/rcmod.py:3
#       1 """Control plot style and scaling using the matplotlib rcParams interface."""
#       2 import functools
# ----> 3 import matplotlib as mpl
#       4 from cycler import cycler
#       5 from . import palettes
#
# File ~/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/matplotlib/__init__.py:998
#     992     _log.debug('loaded rc file %s', fname)
#     994     return config
#     997 rcParamsDefault = _rc_params_in_file(
# --> 998     cbook._get_data_path("matplotlibrc"),
#     999     # Strip leading comment.
#    1000     transform=lambda line: line[1:] if line.startswith("#") else line,
#    1001     fail_on_error=True)
#    1002 rcParamsDefault._update_raw(rcsetup._hardcoded_defaults)
#    1003 rcParamsDefault._ensure_has_backend()
#
# File ~/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/matplotlib/cbook.py:603, in _get_data_path(*args)
#     597 def _get_data_path(*args):
#     598     """
#     599     Return the `pathlib.Path` to a resource file provided by Matplotlib.
#     600
#     601     ``*args`` specify a path relative to the base data path.
#     602     """
# --> 603     return Path(matplotlib.get_data_path(), *args)
#
# File ~/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/matplotlib/_api/__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'get_data_path'

# %%
from train import train_log

acc = train_log(df,model_name="random_forest",epochs=10, batch_size=256)
print(f"Modèle entraîné avec une accuracy de {acc}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from train import train_log
#       3 acc = train_log(df,model_name="random_forest",epochs=10, batch_size=256)
#       4 print(f"Modèle entraîné avec une accuracy de {acc}")
#
# File ~/Documents/Cours/M2/Big Data/Projet/Big_Data_MLOps_Github_API/train_model/train.py:9
#       7 from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
#       8 import pandas as pd
# ----> 9 from models.gradient_boosting import GradientBoostingModel
#      10 from models.random_forest import RandomForestModel
#      11 import numpy as np
#
# File ~/Documents/Cours/M2/Big Data/Projet/Big_Data_MLOps_Github_API/train_model/models/__init__.py:1
# ----> 1 from .gradient_boosting import GradientBoostingModel
#       2 from .random_forest import RandomForestModel
#
# File ~/Documents/Cours/M2/Big Data/Projet/Big_Data_MLOps_Github_API/train_model/models/gradient_boosting.py:4
#       2 from sklearn.preprocessing import LabelEncoder
#       3 import numpy as np
# ----> 4 import matplotlib.pyplot as plt
#       5 from sklearn.model_selection import train_test_split
#       6 from sklearn.ensemble import GradientBoostingClassifier
#
# File ~/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/matplotlib/__init__.py:998
#     992     _log.debug('loaded rc file %s', fname)
#     994     return config
#     997 rcParamsDefault = _rc_params_in_file(
# --> 998     cbook._get_data_path("matplotlibrc"),
#     999     # Strip leading comment.
#    1000     transform=lambda line: line[1:] if line.startswith("#") else line,
#    1001     fail_on_error=True)
#    1002 rcParamsDefault._update_raw(rcsetup._hardcoded_defaults)
#    1003 rcParamsDefault._ensure_has_backend()
#
# File ~/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/matplotlib/cbook.py:603, in _get_data_path(*args)
#     597 def _get_data_path(*args):
#     598     """
#     599     Return the `pathlib.Path` to a resource file provided by Matplotlib.
#     600
#     601     ``*args`` specify a path relative to the base data path.
#     602     """
# --> 603     return Path(matplotlib.get_data_path(), *args)
#
# File ~/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/matplotlib/_api/__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'get_data_path'
