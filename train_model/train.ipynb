# %%
import json
import requests
import pandas as pd

# Charger les données
base_url = "https://api-base-fastapi-mpt-dkhjb0cydga2aydc.canadacentral-01.azurewebsites.net"
api_key = ""

def get_call(paths,url=base_url, params=None, header=None):
    url = f"{base_url}/{paths}"
    response = requests.get(url, params=params, headers=header)
    if response.status_code == 200:
        return response.json()
    elif response.status_code == 403:
        print("La patience est d'or. Enculé")
        response = requests.get(url, params=params, headers=header)
        return response.json()
    else:
        print(f"Error: {response.status_code} - {response.json().get('message', 'Unknown error')}")
        return None
repositories = get_call(paths="show_data",params={"page_size":1000,"page":1})

# %%
print(repositories)
# Out:
# {'page': 1, 'page_size': 10, 'total_pages': 14831, 'total_documents': 148301, 'data': [{'id': 781064102, 'node_id': 'R_kgDOLo4Xpg', 'name': 'CodeLibrary', 'full_name': 'sabbir-noyon/CodeLibrary', 'private': False, 'owner': {'login': 'sabbir-noyon', 'id': 100969574, 'html_url': 'https://github.com/sabbir-noyon'}, 'html_url': 'https://github.com/sabbir-noyon/CodeLibrary', 'description': None, 'fork': False, 'created_at': '2024-04-02T17:21:51Z', 'updated_at': '2025-01-23T23:42:39Z', 'pushed_at': '2024-04-03T16:13:28Z', 'language': 'C', 'forks_count': 2, 'stargazers_count': 9, 'watchers_count': 9, 'open_issues_count': 1}, {'id': 780981597, 'node_id': 'R_kgDOLozVXQ', 'name': 'meticulous-typescript-api', 'full_name': 'MeticulousHome/meticulous-typescript-api', 'private': False, 'owner': {'login': 'MeticulousHome', 'id': 98115466, 'html_url': 'https://github.com/MeticulousHome'}, 'html_url': 'https://github.com/MeticulousHome/meticulous-typescript-api', 'description': 'Typescript / axios based package to interact with the meticulous API', 'fork': False, 'created_at': '2024-04-02T14:26:33Z', 'updated_at': '2025-02-08T13:59:55Z', 'pushed_at': '2025-02-08T14:00:07Z', 'language': 'TypeScript', 'forks_count': 0, 'stargazers_count': 9, 'watchers_count': 9, 'open_issues_count': 0}, {'id': 781057044, 'node_id': 'R_kgDOLo38FA', 'name': 'Portfolio-webpage', 'full_name': 'muhsansattar/Portfolio-webpage', 'private': False, 'owner': {'login': 'muhsansattar', 'id': 90345731, 'html_url': 'https://github.com/muhsansattar'}, 'html_url': 'https://github.com/muhsansattar/Portfolio-webpage', 'description': 'This is portfolio website ', 'fork': False, 'created_at': '2024-04-02T17:06:13Z', 'updated_at': '2024-09-30T09:04:43Z', 'pushed_at': '2024-04-02T17:18:58Z', 'language': 'HTML', 'forks_count': 0, 'stargazers_count': 9, 'watchers_count': 9, 'open_issues_count': 0}, {'id': 780683758, 'node_id': 'R_kgDOLohJ7g', 'name': 'Smart_Causal_Inference', 'full_name': 'CausalInferenceLab/Smart_Causal_Inference', 'private': False, 'owner': {'login': 'CausalInferenceLab', 'id': 114298781, 'html_url': 'https://github.com/CausalInferenceLab'}, 'html_url': 'https://github.com/CausalInferenceLab/Smart_Causal_Inference', 'description': '"실무로 통하는 인과추론 with 파이썬" 스터디를 하고 내용을 정리한 깃허브입니다.', 'fork': False, 'created_at': '2024-04-02T00:52:36Z', 'updated_at': '2024-11-18T06:43:27Z', 'pushed_at': '2024-09-20T12:14:41Z', 'language': 'HTML', 'forks_count': 2, 'stargazers_count': 9, 'watchers_count': 9, 'open_issues_count': 0}, {'id': 780839892, 'node_id': 'R_kgDOLoqr1A', 'name': 'Funny-Eval-Meme', 'full_name': 'Crump3tte/Funny-Eval-Meme', 'private': False, 'owner': {'login': 'Crump3tte', 'id': 157238134, 'html_url': 'https://github.com/Crump3tte'}, 'html_url': 'https://github.com/Crump3tte/Funny-Eval-Meme', 'description': None, 'fork': False, 'created_at': '2024-04-02T09:00:46Z', 'updated_at': '2025-01-15T16:35:25Z', 'pushed_at': '2024-04-02T09:35:08Z', 'language': None, 'forks_count': 3, 'stargazers_count': 9, 'watchers_count': 9, 'open_issues_count': 0}, {'id': 781078326, 'node_id': 'R_kgDOLo5PNg', 'name': 'Bmarket', 'full_name': 'moyu3739/Bmarket', 'private': False, 'owner': {'login': 'moyu3739', 'id': 149601699, 'html_url': 'https://github.com/moyu3739'}, 'html_url': 'https://github.com/moyu3739/Bmarket', 'description': '这是一个使用python爬虫抓取ss市集的脚本', 'fork': False, 'created_at': '2024-04-02T17:52:37Z', 'updated_at': '2025-01-17T04:06:22Z', 'pushed_at': '2024-09-03T07:09:06Z', 'language': 'Python', 'forks_count': 0, 'stargazers_count': 9, 'watchers_count': 9, 'open_issues_count': 1}, {'id': 781018011, 'node_id': 'R_kgDOLo1jmw', 'name': 'Resonance-Stuff', 'full_name': 'The-Original-Reth/Resonance-Stuff', 'private': False, 'owner': {'login': 'The-Original-Reth', 'id': 96796866, 'html_url': 'https://github.com/The-Original-Reth'}, 'html_url': 'https://github.com/The-Original-Reth/Resonance-Stuff', 'description': None, 'fork': False, 'created_at': '2024-04-02T15:42:26Z', 'updated_at': '2 ...

# %%
import pandas as pd
df = pd.DataFrame(repositories['data'])
df.to_pickle("./repositories_data.pkl")
# df = df['language'].value_counts()[df['language'].value_counts()>10]

# %%
import pandas as pd
import numpy
df = pd.read_pickle("./repositories_data.pkl")
df = df[~df["language"].isin(["Python", "None"])]
df = df.dropna(subset=["language"])
df
# Out:
#             id       node_id                                name  \
# 0    766965620  R_kgDOLbb3dA                        ysyx-sdb-tui
# 1    766981394  R_kgDOLbc1Eg                              libcue
# 2    766862104  R_kgDOLbVjGA  kotlin-programming-language-course
# 4    766763227  R_kgDOLbPg2w       asplos24-micro-update-lifting
# 7    766914441  R_kgDOLbYviQ              utxo-payment-interface
# ..         ...           ...                                 ...
# 989  767925592  R_kgDOLcWdWA            circle-to-search-spoofer
# 990  768269739  R_kgDOLcrdqw                         SuperTabBar
# 991  768112558  R_kgDOLch3rg                    template-angular
# 993  767884807  R_kgDOLcT-Bw               DCIC2024-PhotoVoltaic
# 998  768038507  R_kgDOLcdWaw                         nuxt-qrcode
#
#                                       full_name  private  \
# 0                           CSerht/ysyx-sdb-tui    False
# 1                               cue-lang/libcue    False
# 2      vuksa/kotlin-programming-language-course    False
# 4          adwait/asplos24-micro-update-lifting    False
# 7    Marionette-Software/utxo-payment-interface    False
# ..                                          ...      ...
# 989       fillwithjoy1/circle-to-search-spoofer    False
# 990                       daniil108/SuperTabBar    False
# 991                   phaserjs/template-angular    False
# 993                ZongXR/DCIC2024-PhotoVoltaic    False
# 998                       sandros94/nuxt-qrcode    False
#
#                                                  owner  \
# 0    {'login': 'CSerht', 'id': 62015641, 'html_url'...
# 1    {'login': 'cue-lang', 'id': 62243907, 'html_ur...
# 2    {'login': 'vuksa', 'id': 7036941, 'html_url': ...
# 4    {'login': 'adwait', 'id': 32107329, 'html_url'...
# 7    {'login': 'Marionette-Software', 'id': 1431077...
# ..                                                 ...
# 989  {'login': 'fillwithjoy1', 'id': 29514446, 'htm...
# 990  {'login': 'daniil108', 'id': 11629922, 'html_u...
# 991  {'login': 'phaserjs', 'id': 54856938, 'html_ur...
# 993  {'login': 'ZongXR', 'id': 49098045, 'html_url'...
# 998  {'login': 'sandros94', 'id': 13056429, 'html_u...
#
#                                               html_url  \
# 0               https://github.com/CSerht/ysyx-sdb-tui
# 1                   https://github.com/cue-lang/libcue
# 2    https://github.com/vuksa/kotlin-programming-la...
# 4    https://github.com/adwait/asplos24-micro-updat...
# 7    https://github.com/Marionette-Software/utxo-pa...
# ..                                                 ...
# 989  https://github.com/fillwithjoy1/circle-to-sear...
# 990           https://github.com/daniil108/SuperTabBar
# 991       https://github.com/phaserjs/template-angular
# 993    https://github.com/ZongXR/DCIC2024-PhotoVoltaic
# 998           https://github.com/sandros94/nuxt-qrcode
#
#                                            description   fork  \
# 0    A simple tui used for sdb in the ysyx project'...  False
# 1                                                 None  False
# 2                                                 None  False
# 4    Companion artifact for ASPLOS '24: Lifting Mic...  False
# 7    Payment Interface (PI) serves as the middlewar...  False
# ..                                                 ...    ...
# 989  Spoof your device as Pixel 8 Pro to get Circle...  False
# 990                                               None  False
# 991  A Phaser 3 TypeScript project template that us...  False
# 993  本赛题要求选手基于历史光伏发电数据、天气数据、光伏设备空间相对位置等信息，通过建立适当的模型...  False
# 998  A Nuxt module that provides support for genera...  False
#
#                created_at            updated_at             pushed_at  \
# 0    2024-03-04T13:14:15Z  2024-07-26T01:10:24Z  2024-03-11T09:12:55Z
# 1    2024-03-04T13:46:39Z  2024-12-13T00:25:15Z  2024-11-25T14:56:09Z
# 2    2024-03-04T09:13:08Z  2025-01-12T10:31:35Z  2024-05-20T16:14:51Z
# 4    2024-03-04T04:34:26Z  2024-11-29T08:17:27Z  2024-03-04T04:43:22Z
# 7    2024-03-04T11:16:59Z  2024-04-15T16:22:54Z  2024-03-04T12:28:49Z
# ..                    ...                   ...                   ...
# 989  2024-03-06T06:31:13Z  2025-02-03T13:45:27Z  2024-11-29T09:00:30Z
# 990  2024-03-06T19:22:59Z  2025-01-25T12:52:37Z  2024-10-25T14:13:14Z
# 991  2024-03-06T13:47:39Z  2025-02-09T13:54:23Z  2024-11-14T14:46:07Z
# 993  2024-03-06T04:18:34Z  2024-12-20T00:47:36Z  2024-04-09T00:39:36Z
# 998  2024-03-06T11:02:32Z  2025-01-29T14:16:56Z  2024-12-16T21:03:24Z
#
#              language  forks_count  stargazers_count  watchers_count  \
# 0                   C            0                 7               7
# 1                 CUE            0                 7               7
# 2              Kotlin           12                 7               7
# 4             Verilog            1                 7               7
# 7          JavaScript            5                 7               7
# ..                ...          ...               ...             ...
# 989            Kotlin            2                29              29
# 990             Swift            2                28              28
# 991        TypeScript           12                28              28
# 993  Jupyter Notebook            6                28              28
# 998        TypeScript            1                26              26
#
#      open_issues_count
# 0                    0
# 1                    0
# 2                    8
# 4                    0
# 7                    0
# ..                 ...
# 989                  0
# 990                  0
# 991                  1
# 993                  0
# 998                  4
#
# [542 rows x 17 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
sns.countplot(y=df["language"], order=df["language"].value_counts().index)
plt.title("Distribution des langages dans le dataset")
plt.show()

# %%
from train import train_log

acc = train_log(df,model_name="random_forest",epochs=10, batch_size=256)
print(f"Modèle entraîné avec une accuracy de {acc}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from train import train_log
#       3 acc = train_log(df,model_name="random_forest",epochs=10, batch_size=256)
#       4 print(f"Modèle entraîné avec une accuracy de {acc}")
#
# File ~/Documents/Cours/M2/Big Data/Projet/Big_Data_MLOps_Github_API/train_model/train.py:9
#       7 from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
#       8 import pandas as pd
# ----> 9 from models.gradient_boosting import GradientBoostingModel
#      10 from models.random_forest import RandomForestModel
#      11 import numpy as np
#
# File ~/Documents/Cours/M2/Big Data/Projet/Big_Data_MLOps_Github_API/train_model/models/__init__.py:1
# ----> 1 from .gradient_boosting import GradientBoostingModel
#       2 from .random_forest import RandomForestModel
#
# File ~/Documents/Cours/M2/Big Data/Projet/Big_Data_MLOps_Github_API/train_model/models/gradient_boosting.py:4
#       2 from sklearn.preprocessing import LabelEncoder
#       3 import numpy as np
# ----> 4 import matplotlib.pyplot as plt
#       5 from sklearn.model_selection import train_test_split
#       6 from sklearn.ensemble import GradientBoostingClassifier
#
# File ~/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/matplotlib/__init__.py:998
#     992     _log.debug('loaded rc file %s', fname)
#     994     return config
#     997 rcParamsDefault = _rc_params_in_file(
# --> 998     cbook._get_data_path("matplotlibrc"),
#     999     # Strip leading comment.
#    1000     transform=lambda line: line[1:] if line.startswith("#") else line,
#    1001     fail_on_error=True)
#    1002 rcParamsDefault._update_raw(rcsetup._hardcoded_defaults)
#    1003 rcParamsDefault._ensure_has_backend()
#
# File ~/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/matplotlib/cbook.py:603, in _get_data_path(*args)
#     597 def _get_data_path(*args):
#     598     """
#     599     Return the `pathlib.Path` to a resource file provided by Matplotlib.
#     600
#     601     ``*args`` specify a path relative to the base data path.
#     602     """
# --> 603     return Path(matplotlib.get_data_path(), *args)
#
# File ~/miniconda3/envs/MLops_Sini/lib/python3.12/site-packages/matplotlib/_api/__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'get_data_path'
